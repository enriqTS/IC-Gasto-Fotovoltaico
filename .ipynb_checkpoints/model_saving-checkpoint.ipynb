# %% [markdown]
# # Salva o modelo

# %%
#from prophet.serialize import model_from_json
#with open('model.json', 'w') as fout:
#    fout.write(model_to_json(m))

# %% [markdown]
# # Importacao, carregamento e uso do modelo

# %%
from prophet.serialize import model_from_json
from prophet import Prophet

# %%
with open("model.json", "r") as fin:
    m = model_from_json(fin.read())  # Carrega o modelo

# %%
# Realiza a previsao utilizando o modelo
future = m.make_future_dataframe(periods=12, freq="MS")

forecast = m.predict(future)

# %%
ax = forecast.plot(x="ds", y="yhat", label="Predições", legend=True, figsize=(12, 8),xlim=['2026-11-01', '2027-11-01'])

# %%
m.plot(forecast,uncertainty=True);
# Out:
# /home/henrique/miniconda3/envs/ml/lib/python3.12/site-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /home/henrique/miniconda3/envs/ml/lib/python3.12/site-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',
