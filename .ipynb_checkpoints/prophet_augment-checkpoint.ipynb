# %% [markdown]
# # Importacoes

# %%
from prophet import Prophet
from prophet.diagnostics import cross_validation,performance_metrics
from prophet.plot import plot_cross_validation_metric, plot_yearly

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima 
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# # Ajuste do Dataset

# %%
# Lendo os dados
df = pd.read_excel(
    "/home/henrique/IC-Gasto-Fotovoltaico-main/Controle_Faturamento_2023.xlsx",
    sheet_name="Consumo Médio - Clientes",
)

df.drop(df.iloc[:, 48:68], inplace=True, axis=1)
df.drop("Nº Cliente", inplace=True, axis=1)
df.drop("Cliente", inplace=True, axis=1)

df = df.head()

df1 = df.transpose()
df = df1.rename(columns=df1.iloc[0])
df.drop("UC", inplace=True, axis=0)
df.dropna(inplace=True)

df.index
dates = np.array(df.index, dtype="datetime64[D]")
idx = pd.DatetimeIndex(dates)
df["idx"] = idx
df.set_index("idx", inplace=True)
df.index.freq = "MS"

df = pd.concat([df, df])

new_index = pd.date_range(start=df.index.min(), periods=len(df), freq="MS")

df.index = new_index

df.reset_index(inplace=True)
df = df.rename(columns={"index": "DS"})

df.columns = ["ds", "y1", "y2", "y3", "y4", "y5"]

df["y1"] = df["y1"].astype(int)
df["y2"] = df["y2"].astype(int)
df["y3"] = df["y3"].astype(int)
df["y4"] = df["y4"].astype(int)
df["y5"] = df["y5"].astype(int)

df.columns = ["ds", "y", "y2", "y3", "y4", "y5"]

# %% [markdown]
# # Modelo com train/test

# %%
train = df.iloc[:80]
test = df.iloc[79:]

m = Prophet(growth='flat', seasonality_mode='additive',yearly_seasonality=180)

m.fit(train)
future = m.make_future_dataframe(periods=10,freq='MS')
forecast = m.predict(future)
# Out:
# 15:18:34 - cmdstanpy - INFO - Chain [1] start processing
# 15:18:39 - cmdstanpy - INFO - Chain [1] done processing

# %%
ax = forecast.plot(x='ds', y='yhat', label='Predições', legend=True, figsize=(12,8))
test.plot(x='ds',y='y',label='Valores Reais de Teste',legend=True,ax=ax)
train.plot(x='ds',y='y',label='Valores Reais de Treinamento',legend=True,ax=ax)
# Out:
# <Axes: xlabel='ds'>

# %%
df_cv = cross_validation(m,initial="1095 days",period="365 days",horizon="730 days",parallel="processes")
# Out:
# 15:18:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:18:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:18:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:19:27 - cmdstanpy - INFO - Chain [1] done processing

# %%
performance_metrics(df_cv)
# Out:
#     horizon           mse          rmse           mae       mape     mdape  \
# 0   59 days  2.277948e+06   1509.287288   1461.677981   1.059823  1.085284
# 1   89 days  3.214757e+08  17929.742184  10079.297985   9.140239  1.452358
# 2   90 days  3.210615e+08  17918.188501   9819.816794   9.028950  1.364303
# 3  119 days  3.302967e+08  18174.066833  11060.083543  10.089527  3.485458
# 4  120 days  3.292963e+08  18146.521798  10641.996541   9.751297  2.808997
# 5  150 days  9.691983e+06   3113.195019   1778.711840   1.530965  0.344321
# 6  151 days  9.883825e+06   3143.855187   1944.347307   1.562576  0.407545
# 7  180 days  4.949512e+05    703.527698    634.448297   0.370542  0.407545
# 8  181 days  3.383996e+06   1839.564023   1398.995180   0.478541  0.454018
# 9  211 days  5.367312e+06   2316.745959   2031.435797   0.605926  0.588311
# 10 212 days  6.129925e+06   2475.868501   2296.235606   0.665281  0.689636
# 11 242 days  6.072734e+06   2464.291727   2264.480693   0.635129  0.689636
# 12 243 days  3.343963e+06   1828.650697   1629.364450   0.506573  0.512424
# 13 272 days  2.540895e+06   1594.018466   1469.603584   0.459652  0.434164
# 14 273 days  2.070002e+06   1438.750270   1330.379498   0.417001  0.427123
# 15 303 days  2.232976e+06   1494.314622   1411.868369   0.431173  0.455467
# 16 304 days  2.175914e+06   1475.097830   1376.528143   0.441363  0.455467
# 17 333 days  1.141520e+06   1068.419193   1033.511751   0.376020  0.372234
# 18 334 days  1.035055e+06   1017.376569    993.571694   0.433119  0.372234
# 19 364 days  3.242733e+06   1800.759085   1500.610392   1.092486  0.534417
# 20 365 days  3.815454e+06   1953.318791   1737.275544   1.382975  1.115395
# 21 395 days  4.240392e+06   2059.221187   1917.114867   1.612369  1.336339
# 22 396 days  4.143580e+06   2035.578586   1875.749118   1.676782  1.336339
# 23 424 days  1.930472e+06   1389.414335   1206.985682   0.995917  1.081618
# 24 455 days  1.057622e+06   1028.407663    628.121646   0.546515  0.199953
# 25 485 days  5.707741e+04    238.908787    213.081750   0.221045  0.225622
# 26 516 days  6.102075e+05    781.157767    663.469645   0.336477  0.384841
# 27 546 days  4.578275e+06   2139.690458   1904.514575   0.568693  0.536886
# 28 577 days  5.501712e+06   2345.572858   2229.897819   0.663130  0.655522
# 29 608 days  1.728219e+06   1314.617531   1176.219457   0.404761  0.413711
# 30 638 days  7.353445e+05    857.522321    696.619369   0.235676  0.206970
# 31 669 days  8.393825e+05    916.178216    784.119706   0.278612  0.292841
# 32 699 days  8.534060e+05    923.799763    897.565643   0.371030  0.292841
# 33 730 days  1.281021e+06   1131.822023   1029.652885   0.630804  0.449219
#
#        smape  coverage
# 0   1.015562      0.00
# 1   1.372400      0.00
# 2   1.296373      0.25
# 3   1.299137      0.25
# 4   1.146694      0.50
# 5   0.700918      0.50
# 6   0.773429      0.25
# 7   0.427623      0.25
# 8   0.688718      0.00
# 9   0.906825      0.00
# 10  1.021357      0.00
# 11  0.973516      0.00
# 12  0.719794      0.00
# 13  0.622014      0.00
# 14  0.468388      0.00
# 15  0.446663      0.00
# 16  0.431830      0.00
# 17  0.330725      0.00
# 18  0.364121      0.00
# 19  0.581275      0.00
# 20  0.723376      0.00
# 21  0.834843      0.00
# 22  0.866391      0.00
# 23  0.605490      0.25
# 24  0.336333      0.50
# 25  0.198383      0.50
# 26  0.378180      0.25
# 27  0.835383      0.00
# 28  1.009288      0.00
# 29  0.553175      0.25
# 30  0.225206      0.50
# 31  0.250137      0.25
# 32  0.322607      0.00
# 33  0.427263      0.25

# %% [markdown]
# O modelo se torna eficiente após um dataset de 2 anos.

# %% [markdown]
# # Modelo sem train/test

# %%
m = Prophet(growth='flat', seasonality_mode='additive',yearly_seasonality=180)

m.fit(df)

future = m.make_future_dataframe(periods=24,freq='MS')

forecast = m.predict(future)
# Out:
# 15:19:27 - cmdstanpy - INFO - Chain [1] start processing
# 15:19:28 - cmdstanpy - INFO - Chain [1] done processing

# %%
present = m.make_future_dataframe(periods=0,freq='MS')

forecast_present = m.predict(present)

# %%
ax = forecast.plot(x='ds', y='yhat', label='Predições Futuras', legend=True, figsize=(12,8))
forecast_present.plot(x='ds', y='yhat', label='Predições', legend=True, ax=ax)
df.plot(x='ds',y='y',label='Valores Reais',legend=True,ax=ax)
plt.savefig("ProphetAugmentPred.png")

# %%
df_cv = cross_validation(m,initial="1095 days",period="365 days",horizon="730 days",parallel="processes")
# Out:
# 15:19:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:19:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:19:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:19:30 - cmdstanpy - INFO - Chain [1] done processing
# 15:19:31 - cmdstanpy - INFO - Chain [1] done processing
# 15:20:25 - cmdstanpy - INFO - Chain [1] done processing

# %%
performance_metrics(df_cv)
# Out:
#     horizon           mse          rmse           mae       mape     mdape  \
# 0   91 days  6.025541e+07   7762.436117   4911.947835   2.733547  1.172758
